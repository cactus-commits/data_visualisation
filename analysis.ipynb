# %% [markdown]
# do initial EDA
# how many data jobs are there in the data set?
# how many work years are represented?
# which countries exists in this dataset?
# what type of company sizes are there
# ratio of remote work vs office
# average salaries per job role
# median salaries per job role
# seniority level and average salaries?
# remote work and average salaries?
# company location and average salaries?
# clean job titles
# do different visualizations
# export visualizations
# export cleaned data

# %% [markdown]
# # Import pandas and load CSV

# %%
import pandas as pd
df = pd.read_csv('data/salaries.csv')
df.head()
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2024               SE              FT                AI Engineer
# 1       2024               SE              FT                AI Engineer
# 2       2024               SE              FT              Data Engineer
# 3       2024               SE              FT              Data Engineer
# 4       2024               SE              FT  Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  202730             USD         202730                 US             0
# 1   92118             USD          92118                 US             0
# 2  130500             USD         130500                 US             0
# 3   96000             USD          96000                 US             0
# 4  190000             USD         190000                 US             0
#
#   company_location company_size
# 0               US            M
# ...

# %% [markdown]
# # Initial EDA

# %% [markdown]
# #### General info
# - rows
# - colums
# - types
# - not null

# %%
# General info, type and if there anre any null
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16534 entries, 0 to 16533
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           16534 non-null  int64
#  1   experience_level    16534 non-null  str
#  2   employment_type     16534 non-null  str
#  3   job_title           16534 non-null  str
#  4   salary              16534 non-null  int64
#  5   salary_currency     16534 non-null  str
#  6   salary_in_usd       16534 non-null  int64
#  7   employee_residence  16534 non-null  str
#  8   remote_ratio        16534 non-null  int64
#  9   company_location    16534 non-null  str
#  10  company_size        16534 non-null  str
# dtypes: int64(4), str(7)
# memory usage: 1.4 MB

# %%
# Check columns
df.columns
# Out:
# Index(['work_year', 'experience_level', 'employment_type', 'job_title',
#        'salary', 'salary_currency', 'salary_in_usd', 'employee_residence',
#        'remote_ratio', 'company_location', 'company_size'],
#       dtype='str')

# %% [markdown]
# #### Describe
# - only numerical columns used here

# %%
df.describe()
# Out:
#           work_year        salary  salary_in_usd  remote_ratio
# count  16534.000000  1.653400e+04   16534.000000  16534.000000
# mean    2023.226866  1.637270e+05  149686.777973     32.003750
# std        0.713558  3.402057e+05   68505.293156     46.245158
# min     2020.000000  1.400000e+04   15000.000000      0.000000
# 25%     2023.000000  1.017630e+05  101125.000000      0.000000
# 50%     2023.000000  1.422000e+05  141300.000000      0.000000
# 75%     2024.000000  1.872000e+05  185900.000000    100.000000
# max     2024.000000  3.040000e+07  800000.000000    100.000000

# %%
# T stands for transpose: rows <--> columns
df.describe().T
# Out:
#                  count           mean            std      min       25%  \
# work_year      16534.0    2023.226866       0.713558   2020.0    2023.0
# salary         16534.0  163726.962683  340205.744183  14000.0  101763.0
# salary_in_usd  16534.0  149686.777973   68505.293156  15000.0  101125.0
# remote_ratio   16534.0      32.003750      46.245158      0.0       0.0
#
#                     50%       75%         max
# work_year        2023.0    2024.0      2024.0
# salary         142200.0  187200.0  30400000.0
# salary_in_usd  141300.0  185900.0    800000.0
# remote_ratio        0.0     100.0       100.0

# %%
print(f"Rows:{df.shape[0]}), Cols: {df.shape[1]}")
# Out:
# Rows:16534), Cols: 11

# %% [markdown]
# ### 1. How many data jobs are there in the data set?
# - each row is one employee
# - all the jobs in the data set are data jobs

# %%
# Count all rows (all employees)
print(f"Number of employees in dataset: {len(df)}")
# Out:
# Number of employees in dataset: 16534

# %% [markdown]
# ## Explore different categorical columns
# - experience level
# - job_title
# - employment_type
# - employment_resicence
# - revenue_ratio

# %%
import matplotlib

# %%
# .plot() wraps around matplotlib and returns as Axes Instance

df["experience_level"].value_counts().plot(
    kind = "bar", 
    ylabel="Number of employees",
    title="Number of employees by experience level in data field"
    )
ax
# Out:
# <Axes: title={'center': 'Number of employees by experience level in data field'}, xlabel='experience_level', ylabel='Number of employees'>

# %% [markdown]
# -- Total rows
# SELECT COUNT(*) FROM salaries;
#
# -- Unique job titles
# SELECT COUNT(DISTINCT job_title) FROM salaries;

# %% [markdown]
# ### 2. How many work years are represented?

# %%
# Unique yearsjob titles
print(df['work_year'].nunique())
print(df.work_year.head())
# Out:
# 5
# 0    2024
# 1    2024
# 2    2024
# 3    2024
# 4    2024
# Name: work_year, dtype: int64

# %% [markdown]
# ### 3. Which countries exists in this dataset?

# %%
# Unique countries
print(df['work_year'].nunique())
print(df.work_year.head())

# %% [markdown]
# company location and average salaries?

# %% [markdown]
# ## Data Cleaning
#
# - similar titles put together (ex. Data Scientist & Data Science)

# %%
df["job_title"].value_counts().head(10)
# Out:
# job_title
# Data Engineer                3464
# Data Scientist               3314
# Data Analyst                 2440
# Machine Learning Engineer    1705
# Research Scientist            531
# Applied Scientist             435
# Data Architect                435
# Analytics Engineer            431
# Research Engineer             306
# Data Science                  271
# Name: count, dtype: int64

# %%
import duckdb

duckdb.sql("""--sql
    FROM of
    WHERE
).df()
